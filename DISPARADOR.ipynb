# %%
import os
from random import choice
from time import sleep

print('começando...')
ips = ['192.168.0.1',  '192.168.0.2', '192.168.0.3', '192.168.0.4', '192.168.0.5', '192.168.0.6', '192.168.0.7']
escolha = choice(ips)

os.system('sudo su --')
os.system(f'ifconfig wlan')
os.system('sudo service networking restart')
print(f'novo IP: {escolha}')
# Out:
# começando...
# novo IP: 192.168.0.1

# %%
import pandas as pd
contatos_df = pd.read_excel("contatos.xlsx")
display(contatos_df)
# Out:
#      Pessoa         Número                                           Mensagem
# 0       NaN  5562986550071  Temos em sua região disponibilidade da Oi Fibr...
# 1       NaN  5562985490358  Temos em sua região disponibilidade da Oi Fibr...
# 2       NaN  5562985762615  Temos em sua região disponibilidade da Oi Fibr...
# 3       NaN  5562984596410  Temos em sua região disponibilidade da Oi Fibr...
# 4       NaN  5562985312306  Temos em sua região disponibilidade da Oi Fibr...
# ..      ...            ...                                                ...
# 145     NaN  5562986012792  Temos em sua região disponibilidade da Oi Fibr...
# 146     NaN  5562984662061  Temos em sua região disponibilidade da Oi Fibr...
# 147     NaN  5562986074247  Temos em sua região disponibilidade da Oi Fibr...
# 148     NaN  5562986650263  Temos em sua região disponibilidade da Oi Fibr...
# 149     NaN  5562984720304  Temos em sua região disponibilidade da Oi Fibr...
#
# [150 rows x 3 columns]

# %%
from selenium import webdriver

from selenium.webdriver.common.keys import Keys
import time
import urllib

navegador = webdriver.Chrome()
navegador.get("https://www.oi.com.br/negociacao/")

while len(navegador.find_elements_by_id("side")) < 1:
    time.sleep(1)


for i, mensagem in enumerate(contatos_df['Mensagem']):
    pessoa = contatos_df.loc[i, "Pessoa"]
    numero = contatos_df.loc[i, "Número"]
    texto = urllib.parse.quote(f"Olá tudo bem?{mensagem}")
    link = f"https://web.whatsapp.com/send?phone={numero}&text={texto}"
    navegador.get(link)
    time.sleep(5)
   
    while len(navegador.find_elements_by_id("side")) < 1:
        time.sleep(5)
    try:
        navegador.find_element_by_xpath('//*[@id="main"]/footer/div[1]/div[2]/div/div[1]/div/div[2]').send_keys(Keys.ENTER)
        time.sleep(25)
    except:
        print("Erro URL")
        time.sleep(1)
# Out:
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
# Erro URL
